# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/aparrish/vsketch
# Out:
# Collecting git+https://github.com/aparrish/vsketch
#   Cloning https://github.com/aparrish/vsketch to /private/var/folders/x9/9jxql1vx7pq2hspk458v48x40000gn/T/pip-req-build-cv2iivsu
#   Running command git clone --filter=blob:none --quiet https://github.com/aparrish/vsketch /private/var/folders/x9/9jxql1vx7pq2hspk458v48x40000gn/T/pip-req-build-cv2iivsu
#   Resolved https://github.com/aparrish/vsketch to commit 852a0aa516fe021e230e277de1b3ca8314cbb10b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vpype@ git+https://github.com/abey79/vpype/@master (from vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Cloning https://github.com/abey79/vpype/ (to revision master) to /private/var/folders/x9/9jxql1vx7pq2hspk458v48x40000gn/T/pip-install-d_g_hlv0/vpype_c9bf4384d3a840188590cd9baffd94e9
#   Running command git clone --filter=blob:none --quiet https://github.com/abey79/vpype/ /private/var/folders/x9/9jxql1vx7pq2hspk458v48x40000gn/T/pip-install-d_g_hlv0/vpype_c9bf4384d3a840188590cd9baffd94e9
#   Resolved https://github.com/abey79/vpype/ to commit 3dbc352d3e4f37c20ff3d28e7f56235da2c139ed
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: PySide6>=6.3.2 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vsketch==1.1.0) (6.8.2.1)
# Requirement already satisfied: Shapely>=1.8.2 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from Shapely[vectorized]>=1.8.2->vsketch==1.1.0) (2.0.7)
# Requirement already satisfied: cookiecutter>=2.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vsketch==1.1.0) (2.6.0)
# Requirement already satisfied: matplotlib>=3.3.3 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vsketch==1.1.0) (3.9.2)
# Requirement already satisfied: multiprocess>=0.70 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vsketch==1.1.0) (0.70.17)
# Requirement already satisfied: numpy<3,>=1.20.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vsketch==1.1.0) (2.1.3)
# Requirement already satisfied: pnoise>=0.2.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vsketch==1.1.0) (0.2.0)
# Requirement already satisfied: watchfiles>=0.12 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vsketch==1.1.0) (1.0.4)
# Requirement already satisfied: binaryornot>=0.4.4 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (0.4.4)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (3.1.4)
# Requirement already satisfied: click<9.0.0,>=7.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (8.1.8)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (6.0.2)
# Requirement already satisfied: python-slugify>=4.0.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (8.0.4)
# Requirement already satisfied: requests>=2.23.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (2.32.3)
# Requirement already satisfied: arrow in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (1.3.0)
# Requirement already satisfied: rich in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (13.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (2.9.0)
# Requirement already satisfied: dill>=0.3.9 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from multiprocess>=0.70->vsketch==1.1.0) (0.3.9)
# Requirement already satisfied: shiboken6==6.8.2.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from PySide6>=6.3.2->vsketch==1.1.0) (6.8.2.1)
# Requirement already satisfied: PySide6-Essentials==6.8.2.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from PySide6>=6.3.2->vsketch==1.1.0) (6.8.2.1)
# Requirement already satisfied: PySide6-Addons==6.8.2.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from PySide6>=6.3.2->vsketch==1.1.0) (6.8.2.1)
# WARNING: shapely 2.0.7 does not provide the extra 'vectorized'
# Requirement already satisfied: anyio>=3.0.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from watchfiles>=0.12->vsketch==1.1.0) (4.4.0)
# Requirement already satisfied: asteval>=0.9.26 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (1.0.6)
# Requirement already satisfied: cachetools>=4.2.2 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (5.5.2)
# Requirement already satisfied: pyphen<0.16,>=0.14 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (0.15.0)
# Requirement already satisfied: scipy>=1.6 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (1.15.2)
# Requirement already satisfied: svgelements>=1.6.10 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (1.9.6)
# Requirement already satisfied: svgwrite<2.0,>=1.4 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (1.4.3)
# Requirement already satisfied: tomli>=2.0.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (2.0.1)
# Requirement already satisfied: glcontext>=2.3.2 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (3.0.0)
# Requirement already satisfied: moderngl!=5.7.1,!=5.7.2,>=5.6.2 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0) (5.12.0)
# Requirement already satisfied: idna>=2.8 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from anyio>=3.0.0->watchfiles>=0.12->vsketch==1.1.0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from anyio>=3.0.0->watchfiles>=0.12->vsketch==1.1.0) (1.3.1)
# Requirement already satisfied: chardet>=3.0.2 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from binaryornot>=0.4.4->cookiecutter>=2.1->vsketch==1.1.0) (5.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter>=2.1->vsketch==1.1.0) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->vsketch==1.1.0) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from python-slugify>=4.0.0->cookiecutter>=2.1->vsketch==1.1.0) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.1.0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.1.0) (2025.1.31)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from arrow->cookiecutter>=2.1->vsketch==1.1.0) (2.9.0.20240821)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from rich->cookiecutter>=2.1->vsketch==1.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from rich->cookiecutter>=2.1->vsketch==1.1.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->cookiecutter>=2.1->vsketch==1.1.0) (0.1.2)

# %%
import sys
# !{sys.executable} -m pip install --upgrade https://github.com/aparrish/bezmerizing/archive/main.zip
# Out:
# Collecting https://github.com/aparrish/bezmerizing/archive/main.zip
#   Using cached https://github.com/aparrish/bezmerizing/archive/main.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy>=1.1.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from bezmerizing==0.2.0) (1.15.2)
# Requirement already satisfied: numpy>=1.16.0 in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (from bezmerizing==0.2.0) (2.1.3)

# %%
import random
import vsketch
import bezmerizing

# %%
from math import sin, cos, radians
from numpy.random import randint

# %%
from numpy.random import uniform, normal, choice
import numpy as np

# %%
from scipy.stats import truncnorm
def t_normal(a, b, mu, sigma):
    tn = truncnorm((a-mu)/sigma, (b-mu)/sigma, loc=mu, scale=sigma)
    return tn.rvs(1)[0]

# %%
def uniform_glyph_baseline(n=10):
    pts = [[-0.4, 0.5], [0.4, 0.5]]
    for i in range(n):
        pts.append([uniform(-0.5, 0.5), uniform(-0.5, 0.5)])
    return pts

# %%
glyph_count = 100
glyph_widths = [choice([0.2, 0.333, 0.667, 1], p=[0.1, 0.5, 0.3, 0.1]) for i in range(glyph_count)]
glyph_widths[:12]
# Out:
# [np.float64(0.667),
#  np.float64(0.667),
#  np.float64(0.667),
#  np.float64(0.333),
#  np.float64(0.333),
#  np.float64(0.333),
#  np.float64(0.333),
#  np.float64(0.333),
#  np.float64(0.333),
#  np.float64(0.333),
#  np.float64(1.0),
#  np.float64(0.667)]

# %%
def baseline_glyph_varwidth(n=10, width=1.0):
    pts = [[0, 0], [width, 0]]
    for i in range(n):
        pts.append([uniform(0, width), uniform(0, -1)])
    return pts

# %%
def grid_glyph():
    pts = []
    for i in range(int(t_normal(4, 12, 8, 2))):
        x = (choice([-0.5, 0, 0.5]))
        y = (choice([-0.5, 0, 0.5]))
        pts.append([x, y])
    return pts

# %%
width = 100
height = 100
grid_size = 10

cell_size_x = width / grid_size
cell_size_y = height / grid_size

scale_val = (width / grid_size) * 0.6

vsk = vsketch.Vsketch()
vsk.size(f"{width}mm", f"{height}mm")
vsk.scale("1mm")

for i in range(grid_size):
    for j in range(grid_size):
        glyph = grid_glyph()
        smooth = (
            bezmerizing.Polyline(glyph)
            .augment()
            .catmull_spline(tightness=-0.5)
            .to_polyline(10)
        )
        with vsk.pushMatrix():
            vsk.translate(i * cell_size_x, j * cell_size_y)
            vsk.scale(scale_val)
            vsk.polygon(smooth)
vsk.display(fig_size=(6, 6))

# %%
def make_scribble(width, height, steps, stddev=0):
    pts = []
    for i in range(steps):
        x = ((width / steps) * i) + normal(0, stddev)
        y = normal(0, height)
        pts.append([x, y])
    return pts

# %%
vsk = vsketch.Vsketch()
vsk.size("200mm", "80mm")
vsk.scale("1mm")
pts = make_scribble(width=180, height=10, steps=50, stddev=0)
vsk.polygon(pts)
vsk.display()

# %%
vsk = vsketch.Vsketch()
vsk.size("200mm", "80mm")
vsk.scale("1mm")
pts = make_scribble(width=180, height=10, steps=50, stddev=0)
curve_pts = bezmerizing.Polyline(pts).catmull_spline(tightness=-0.5).to_polyline(10)
vsk.polygon(curve_pts)
vsk.display()

# %%
vsk = vsketch.Vsketch()
vsk.size("200mm", "80mm")
vsk.scale("1mm")
pts = make_scribble(width=180, height=10, steps=50, stddev=5)
curve_pts = bezmerizing.Polyline(pts).catmull_spline(tightness=-0.5).to_polyline(10)
vsk.polygon(curve_pts)
vsk.display()

# %%
vsk = vsketch.Vsketch()
vsk.size("200mm", "320mm")
vsk.scale("1mm")
for i in range(15):
    pts = make_scribble(width=180, height=5, steps=int(uniform(25, 100)), stddev=i * 0.5)
    curve_pts = bezmerizing.Polyline(pts).catmull_spline(tightness=uniform(-4, 1)).to_polyline(10)
    vsk.strokeWeight(choice([1, 2, 3]))
    with vsk.pushMatrix():
        vsk.translate(0, i * 20)
        vsk.polygon(curve_pts)
vsk.display(fig_size=(6, 10))

# %% [markdown]
# # Writing Notes
# ## A piece trying to simulate human notation process while writing and reading

# %%
import sys
import random
import vsketch
import bezmerizing
import numpy as np
from numpy.random import uniform, normal, choice
from scipy.stats import truncnorm
import math

# %%
def t_normal(a, b, mu, sigma):
    tn = truncnorm((a-mu)/sigma, (b-mu)/sigma, loc=mu, scale=sigma)
    return tn.rvs(1)[0]

# %% [markdown]
# create canvas

# %%
width = 210 
height = 297 
margin = 8
vsk = vsketch.Vsketch()
vsk.size(f"{width}mm", f"{height}mm")
vsk.scale("1mm")

# %% [markdown]
# function to generate handwritten character

# %%
def handwritten_char(width_factor=0.8, height_factor=1.0, complexity=None):
    if complexity is None:
        complexity = int(t_normal(3, 8, 5, 1.5))
    pts = []
    pts.append([0, 0])
    
    # add random points
    for i in range(complexity):
        x = uniform(0, width_factor)
        y = uniform(-height_factor, 0) if i % 2 == 0 else uniform(0, height_factor * 0.3)
        pts.append([x, y])
    
    # humanize a bit
    for i in range(1, len(pts)):
        pts[i][0] += uniform(-0.05, 0.05)
        pts[i][1] += uniform(-0.05, 0.05)
    
    # create smooth curves
    smooth = (
        bezmerizing.Polyline(pts)
        .augment()
        .catmull_spline(tightness=uniform(-0.6, -0.2))
        .to_polyline(10)
    )
    
    return smooth, width_factor

# %% [markdown]
# function to draw handwritten words

# %%
def draw_handwritten_word(vsk, x, y, chars_count, char_width=4, char_height=6, spacing=0.8):
    current_x = x
    
    for i in range(chars_count):
        # randomize character width slightly
        width_factor = uniform(0.3, 0.7)
        height_factor = uniform(0.3, 0.6)
        
        char, width = handwritten_char(width_factor, height_factor)
        
        with vsk.pushMatrix():
            vsk.translate(current_x, y)
            vsk.scale(char_width, char_height)
            # slightly randomize rotation
            vsk.rotate(uniform(-0.05, 0.05))
            vsk.polygon(char)
        
        current_x += char_width * width_factor * spacing + uniform(0, 0.5)
    
    return current_x - x

# %% [markdown]
# Function to create a random underline

# %%
def draw_underline(vsk, x, y, length, waviness=0.5):
    pts = []
    num_points = int(length / 5) + 2
    
    for i in range(num_points):
        pos_x = x + (i * length / (num_points - 1))
        pos_y = y + uniform(-waviness, waviness)
        pts.append([pos_x, pos_y])
    
    smooth = (
        bezmerizing.Polyline(pts)
        .augment()
        .catmull_spline(tightness=-0.25)
        .to_polyline(int(length / 2))
    )
    
    vsk.polygon(smooth)

# %% [markdown]
# Function to create a circled annotation

# %%
def draw_circle(vsk, center_x, center_y, radius_x, radius_y=None, irregularity=0.8):
    if radius_y is None:
        radius_y = radius_x
    
    # create points on the circle
    num_points = int(t_normal(15, 30, 20, 5))
    pts = []
    
    for i in range(num_points):
        angle = 2 * math.pi * i / num_points
        # add randomness
        r_x = radius_x * (1 + uniform(-irregularity/2, irregularity/2) * 0.2)
        r_y = radius_y * (1 + uniform(-irregularity/2, irregularity/2) * 0.2)
        
        x = center_x + r_x * math.cos(angle)
        y = center_y + r_y * math.sin(angle)
        
        # slight imperfection
        x += uniform(-irregularity, irregularity)
        y += uniform(-irregularity, irregularity)
        
        pts.append([x, y])
    
    pts.append(pts[0])
    
    # create smooth curves
    smooth = (
        bezmerizing.Polyline(pts)
        .augment()
        .catmull_spline(tightness=t_normal(-0.5, -0.1, -0.3, 0.1))
        .to_polyline(6)
    )
    
    vsk.polygon(smooth)

# %% [markdown]
# Function to create a curved bracket in the margin

# %%
def draw_bracket(vsk, x, y, height, right_facing=False, curvature=0.3):
    num_points = int(height / 5) + 2
    pts = []
    
    for i in range(num_points):
        pos_y = y + (i * height / (num_points - 1))
        curve_factor = i / (num_points - 1)  #0 to 1
        curve_amount = math.sin(curve_factor * math.pi) * curvature
        
        if right_facing:
            pos_x = x - curve_amount * 10
        else:
            pos_x = x + curve_amount * 10
            
        pos_x += uniform(-0.3, 0.3)
        pos_y += uniform(-0.3, 0.3)
        
        pts.append([pos_x, pos_y])
    
    smooth = (
        bezmerizing.Polyline(pts)
        .augment()
        .catmull_spline(tightness=-0.25)
        .to_polyline(int(height * 2))
    )
    
    vsk.polygon(smooth)

# %% [markdown]
# Function to create a squiggly line (for emphasis)

# %%
def draw_squiggle(vsk, x, y, length, amplitude=2, frequency=0.2):
    pts = []
    num_points = int(length / 2) + 2
    
    for i in range(num_points):
        pos_x = x + (i * length / (num_points - 1))
        # create a wave
        pos_y = y + math.sin(i * frequency * math.pi) * amplitude
        pos_y += uniform(-0.5, 0.5)
        
        pts.append([pos_x, pos_y])
    
    # create smooth curves
    smooth = (
        bezmerizing.Polyline(pts)
        .augment()
        .catmull_spline(tightness=-0.3)
        .to_polyline(int(length * 2))
    )
    
    vsk.polygon(smooth)

# %% [markdown]
# Add some underlines

# %%
for _ in range(4):
    # choose random position for underline
    x = margin + 15 + uniform(0, width - 2*margin - 80)
    y = margin + 30 + uniform(10, height - 2*margin - 50)
    length = uniform(30, 80)
    
    vsk.stroke(2)
    draw_underline(vsk, x, y, length, waviness=0.8)

# %% [markdown]
# Add some circles around "words"

# %%
for _ in range(3):
    x = margin + 40 + uniform(0, width - 2 * margin - 100)
    y = margin + 12 + uniform(20, height - 2 * margin - 70)
    rx = uniform(10, 25)
    ry = uniform(2, 4)
    
    vsk.stroke(1)
    draw_circle(vsk, x, y, rx, ry)

# %% [markdown]
# Add margin notes

# %%
right_margin_x = width - margin - 40
for _ in range(20):
    y = margin + 40 + uniform(0, height - 2 *margin - 80)
    word_length = random.randint(8, 12)
    
    vsk.stroke(1)
    draw_handwritten_word(vsk, right_margin_x, y, word_length)

# %% [markdown]
# Add brackets in margins

# %%
for _ in range(2):
    x = margin + 5
    y = margin + 50 + uniform(0, height - 2*margin - 100)
    bracket_height = uniform(20, 50)
    
    vsk.stroke(1)
    draw_bracket(vsk, x, y, bracket_height)

# %% [markdown]
# Add squiggly emphasis lines

# %%
for _ in range(3):
    x = margin + 20 + uniform(0, width - 2*margin - 90)
    y = margin + 40 + uniform(0, height - 2*margin - 80)
    length = uniform(20, 60)
    
    vsk.stroke(1)
    draw_squiggle(vsk, x, y, length)

# %% [markdown]
# Add exclamation points in margins

# %%
for _ in range(2):
    x = width - margin - 15
    y = margin + 60 + uniform(0, height - 2*margin - 120)
    
    vsk.line(x, y - 5, x, y - 1)
    vsk.ellipse(x, y, 0.5, 0.5)

# %% [markdown]
# Add more detailed notes at the bottom of the page

# %%
bottom_note_y = height - margin - 30
bottom_note_x = margin + 30

# %% [markdown]
# Add handwritten circles in a few places (more circular than the previous ones)

# %%
for _ in range(2):
    x = margin + 40 + uniform(0, width - 2*margin - 100)
    y = margin + 10 + uniform(0, height - 2*margin - 100)
    radius = uniform(8, 10)
    vsk.stroke(1)
    draw_circle(vsk, x, y, 4, 1, irregularity=0.2)

# %%
vsk.display(fig_size=(16, 22))
