# %% [markdown]
# # Text<>MIDI

# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in /Users/yifan/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (2.6.1)

# %%
import pygame
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def play_midi(file_path):
    pygame.mixer.init()
    pygame.mixer.music.load(file_path)
    pygame.mixer.music.play()

# %% [markdown]
# using pygame to play midi

# %% [markdown]
# ## MIDI File Structures

# %%
play_midi('piano.mid')

# %% [markdown]
# original file

# %%
midi_txt = open("piano.mid", "rb").read()

# %%
print(midi_txt)
# Out:
# b"MThd\x00\x00\x00\x06\x00\x00\x00\x01\x00`MTrk\x00\x00\x03\xca\x00\xff\x03\x05piano\x00\xffX\x04\x04\x02$\x08\x00\xffX\x04\x04\x02$\x08\x00\x90'@\x00\x90.G\x00\x903H\x00\x907B\x00\x90?I_\x807@\x01\x80.@\x00\x90.C\x00\x803@\x00\x903H\x00\x9078\x00\x80?@\x00\x90?M_\x80'@)\x807@\x04\x80?@\x04\x803@\x00\x903O\x00\x907P\x00\x90:O\x00\x90?T*\x80.@\x02\x807@\x10\x803@\x1a\x80:@\x01\x80?@\t\x900Q\x00\x905F\x00\x9086\x00\x90:E\x00\x90?I`\x80:@&\x808@8\x800@\x00\x805@\x02\x900Q\x00\x905C\x00\x908E\x00\x80?@\x00\x90?OX\x808@\x05\x800@\x00\x80?@\x03\x900I\x00\x90:O\x00\x90?SA\x80:@\x1c\x80?@\x00\x805@\x03\x903M\x00\x90<M\x00\x90?M\x00\x800@\x81\x0c\x803@\x04\x903G\x81\x0c\x80?@\x04\x90?KY\x80?@\x01\x803@\x00\x80<@\x06\x90:D\x00\x90<K\x00\x90?J\x81@\x903P\x00\x80:@\x00\x90:D\x00\x80<@\x00\x90<E\x00\x80?@\x00\x90?RX\x80:@\x02\x80<@\x00\x80?@\x06\x908E\x00\x90:S\x00\x90<Y\x00\x90?T\x00\x90V>'\x803@\x0c\x808@\x0b\x80<@ \x80:@\x00\x80?@\x00\x80V@\x02\x90.K\x00\x903@\x00\x9073\x00\x90:I\x00\x90?M\x00\x90C8\x00\x90V;0\x90'AP\x80.@\x03\x803@\x00\x807@\x04\x80V@\x02\x80'@\x01\x80:@\x00\x80?@\x00\x80C@\x06\x90'D\x00\x90.J\x00\x903N\x00\x907=\x00\x90:M\x00\x90?R\x00\x90CD\x81\x04\x80.@\x02\x80C@\x02\x807@\x04\x803@\x00\x80:@\x04\x903Q\x00\x907F\x00\x90:Q\x00\x90C@\x00\x90RG%\x807@\x02\x80'@\t\x90'<\x00\x90/A\x0f\x80C@\n\x803@\x07\x80/@\r\x80?@\x02\x80:@\x01\x900P\x00\x905K\x00\x908A\x00\x90?K\x00\x80R@\x00\x90RF\x02\x80'@F\x80R@D\x808@4\x90(7\x00\x800@\x00\x900O\x00\x908G\x00\x80?@\x00\x90?M\x00\x90KHW\x800@\x00\x808@\x00\x80?@\x00\x80K@\x01\x80(@\x08\x900G\x00\x908Q\x00\x90?N\x00\x90KM-\x808@\x03\x90(:(\x800@\x01\x805@\x02\x80?@\x00\x80K@\x05\x903P\x00\x90:\\\x00\x90?O\x00\x90KD\x01\x80(@'\x803@\x01\x80:@\x07\x903H\x00\x90<J\\\x80?@\x00\x80K@\x04\x803@\x00\x903Q\x00\x90:O\x00\x80<@\x00\x90<Q\x00\x90?M\x00\x90KL\x81\x0c\x803@\x00\x80:@\x00\x80?@\x00\x80K@\x04\x90+,\x00\x903D\x00\x908;\x00\x90:R\x00\x90?U\x00\x90KBR\x80+@\x05\x808@\x05\x80<@\x01\x803@\x00\x80:@\x00\x80?@\x00\x80K@\x03\x903H\x00\x908A\x00\x90:J\x00\x90<P\x00\x90?J\x00\x90KBc\x808@\\\x80K@\x01\x803@\x00\x903B\x00\x80:@\x00\x90:T\x00\x80?@\x00\x90?R\x00\x90KdT\x80K@\x06\x803@\x01\x80?@\x02\x80:@\x02\x80<@\x01\x903N\x00\x908K\x00\x90:R\x00\x90<O\x00\x90?S\x00\x90Od)\x808@\x07\x902S\x02\x80<@\x05\x803@!\x802@\x01\x80:@\x07\x90'>\x00\x900S\x00\x90:Z\x00\x80?@\x00\x90?W\x00\x80O@%\x80'@\x08\x800@\x02\x80:@\x00\x80?@\x00\xff/\x00\x01MThd\x00\x00\x00\x06\x00\x00\x00\x01\x00`MTrk\x00\x00\x03\xca\x00\xff\x03\x05piano\x00\xffX\x04\x04\x02$\x08\x00\xffX\x04\x04\x02$\x08\x00\x90'@\x00\x90.G\x00\x903H\x00\x907B\x00\x90?I_\x807@\x01\x80.@\x00\x90.C\x00\x803@\x00\x903H\x00\x9078\x00\x80?@\x00\x90?M_\x80'@)\x807@\x04\x80?@\x04\x803@\x00\x903O\x00\x907P\x00\x90:O\x00\x90?T*\x80.@\x02\x807@\x10\x803@\x1a\x80:@\x01\x80?@\t\x900Q\x00\x905F\x00\x9086\x00\x90:E\x00\x90?I`\x80:@&\x808@8\x800@\x00\x805@\x02\x900Q\x00\x905C\x00\x908E\x00\x80?@\x00\x90?OX\x808@\x05\x800@\x00\x80?@\x03\x900I\x00\x90:O\x00\x90?SA\x80:@\x1c\x80?@\x00\x805@\x03\x903M\x00\x90<M\x00\x90?M\x00\x800@\x81\x0c\x803@\x04\x903G\x81\x0c\x80?@\x04\x90?KY\x80?@\x01\x803@\x00\x80<@\x06\x90:D\x00\x90<K\x00\x90?J\x81@\x903P\x00\x80:@\x00\x90:D\x00\x80<@\x00\x90<E\x00\x80?@\x00\x90?RX\x80:@\x02\x80<@\x00\x80?@\x06\x908E\x00\x90:S\x00\x90<Y\x00\x90?T\x00\x90V>'\x803@\x0c\x808@\x0b\x80<@ \x80:@\x00\x80?@\x00\x80V@\x02\x90.K\x00\x903@\x00\x9073\x00\x90:I\x00\x90?M\x00\x90C8\x00\x90V;0\x90'AP\x80.@\x03\x803@\x00\x807@\x04\x80V@\x02\x80'@\x01\x80:@\x00\x80?@\x00\x80C@\x06\x90'D\x00\x90.J\x00\x903N\x00\x907=\x00\x90:M\x00\x90?R\x00\x90CD\x81\x04\x80.@\x02\x80C@\x02\x807@\x04\x803@\x00\x80:@\x04\x903Q\x00\x907F\x00\x90:Q\x00\x90C@\x00\x90RG%\x807@\x02\x80'@\t\x90'<\x00\x90/A\x0f\x80C@\n\x803@\x07\x80/@\r\x80?@\x02\x80:@\x01\x900P\x00\x905K\x00\x908A\x00\x90?K\x00\x80R@\x00\x90RF\x02\x80'@F\x80R@D\x808@4\x90(7\x00\x800@\x00\x900O\x00\x908G\x00\x80?@\x00\x90?M\x00\x90KHW\x800@\x00\x808@\x00\x80?@\x00\x80K@\x01\x80(@\x08\x900G\x00\x908Q\x00\x90?N\x00\x90K ...

# %% [markdown]
# ### MIDI header chunk
# MThd\x00\x00\x00\x06\x00\x00\x00\x01\x00`
# #### MThd
# header identifier
# #### \x00\x00\x00\x06
# four bytes indicating the chunk length (in this case 6 bytes)
# #### \x00\x00:
# MIDI format type, 0 means single-track
# #### \x00\x01:
# number of tracks (1 track)
# #### `\x00`` (0x60 in hex = 96):
#
# ticks per quarter note (timing resolution)
# #### MTrk
#
# track chunk identifier

# %% [markdown]
# ## Manipulating MIDI

# %% [markdown]
# ### MIDI Encoding
# #### MIDI uses a single byte (8 bits) encoding, ranges from 0 to 127, 0x00 to 0x7F in hexadecimal.
# #### It follows [Status Byte] [Note Number] [Velocity]. MIDI keyboards usually use 64 as the default or neutral velocity.
# #### Note-on: 0x90, Note-off: 0x80
# example: 0x90 3C 40 means Note-On, Middle C, Velocity 64.

# %%
import random

# %%
midi_data = bytearray(open("piano.mid", "rb").read())

# %% [markdown]
# convert to bytearray
# bytearray: https://www.programiz.com/python-programming/methods/built-in/bytearray

# %%
for i in range(len(midi_data) - 2):
    if midi_data[i] in [0x90, 0x80]:  # detect if the note is on or off
        midi_data[i+1] = random.randint(0, 10)  # randomize the pitch

# %%
with open("modified_piano.mid", "wb") as file:
    file.write(midi_data)

# %% [markdown]
# write midi data

# %%
play_midi("modified_piano.mid")

# %% [markdown]
# ### MIDI to Text

# %%
latin_text = open("piano.mid", "r", encoding="latin1").read()

# %%
print(latin_text)
# Out:
# MThd`MTrkÊÿpianoÿXÿX'@.G3H7B?I_7@.@.C3@3H78?@?M_'@)7@?@3@3O7P:O?T*.@7@3@:@?@	0Q5F86:E?I`:@&8@80@5@0Q5C8E?@?OX8@0@?@0I:O?SA:@?@5@3M<M?M0@3@3G?@?KY?@3@<@:D<K?J@3P:@:D<@<E?@?RX:@<@?@8E:S<Y?TV>'3@8@<@ :@?@V@.K3@73:I?MC8V;0'AP.@3@7@V@'@:@?@C@'D.J3N7=:M?RCD.@C@7@3@:@3Q7F:QC@RG%7@'@	'</AC@
# 3@/@
# ?@:@0P5K8A?KR@RF'@FR@D8@4(70@0O8G?@?MKHW0@8@?@K@(0G8Q?NKM-8@(:(0@5@?@K@3P:\?OKD(@'3@:@3H<J\?@K@3@3Q:O<@<Q?MKL3@:@?@K@+,3D8;:R?UKBR+@8@<@3@:@?@K@3H8A:J<P?JKBc8@\K@3@3B:@:T?@?RKdTK@3@?@:@<@3N8K:R<O?SOd)8@2S<@3@!2@:@'>0S:Z?@?WO@%'0@:@?@ÿ/

# %% [markdown]
# ### MIDI to Image

# %%
from PIL import Image, ImageOps, ImageFilter

# %%
piano_bytes = open("piano.mid", "rb").read()

# %%
width = 30
padded_text_bytes = piano_bytes + (b' ' * width * 3)
height = int((len(padded_text_bytes) / 3) / width)

# %%
piano_img = Image.frombytes('RGB', (width, height), padded_text_bytes)

# %%
def show_scaled(img, scale=20):
    return img.resize((img.width*scale, img.height*scale))

# %%
show_scaled(piano_img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x240>

# %%
modified_piano_bytes = open("modified_piano.mid", "rb").read()

# %%
width = 30
padded_text_bytes = modified_piano_bytes + (b' ' * width * 3)
height = int((len(padded_text_bytes) / 3) / width)
modified_piano_img = Image.frombytes('RGB', (width, height), padded_text_bytes)
show_scaled(modified_piano_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 width = 30
# ----> 2 padded_text_bytes = modified_piano_bytes + (b' ' * width * 3)
#       3 height = int((len(padded_text_bytes) / 3) / width)
#       4 modified_piano_img = Image.frombytes('RGB', (width, height), padded_text_bytes)
#
# NameError: name 'modified_piano_bytes' is not defined

# %%
def show_scaled(img, scale=20):
    return img.resize((img.width*scale, img.height*scale))
show_scaled(modified_piano_img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x20>

# %%
width = 30 # arbitrary, adjust to taste
padded_text_bytes = modified_piano_bytes + (b' ' * width * 3)
height = int((len(padded_text_bytes) / 3) / width)
modified_piano_img = Image.frombytes('RGB', (width, height), padded_text_bytes)

# %%
def show_scaled(img, scale=20):
    return img.resize((img.width*scale, img.height*scale))
show_scaled(modified_piano_img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x240>

# %%
modified_piano_img.save("modified_piano_img.png")

# %% [markdown]
# ## Text to MIDI

# %%
text = "hi this is joe"

# %%
filename="output.mid"

# %%
header_chunk = b"MThd" + b"\x00\x00\x00\x06" + b"\x00\x00" + b"\x00\x01" + b"\x01\xE0"
track_data = b"" #this is a place holder, empty byte string

# %% [markdown]
# 1. header chunk identifier + header chunk size: 6 bytes + MIDI format: single-track file +  1 track + tempo: 480 ticks per quarter note

# %%
for char in text:
    midi_note = (ord(char) % 128) 
    track_data += b"\x00" + bytes([0x90, midi_note, 64]) #note on
    track_data += b"\x20" + bytes([0x80, midi_note, 64]) #note off

# %% [markdown]
# 2. converts the character to a MIDI note
# 3. b"\x00" + bytes([0x90, midi_note, 64]) creates a note-on event at velocity 64
# 4. b"\x20" + bytes([0x80, midi_note, 64]) creates a note-off event after some delay as of \x20

# %%
track_data += b"\x00\xFF\x2F\x00"

# %% [markdown]
# 5. add an end mark to the track

# %%
track_chunk = b"MTrk" + bytes([
    (len(track_data) >> 24) & 0xFF,
    (len(track_data) >> 16) & 0xFF,
    (len(track_data) >> 8) & 0xFF,
    len(track_data) & 0xFF
]) + track_data

# %% [markdown]
# 7. b"MTrk" is the track chunk identifier
# 8. parse track data length in 4 bytes
# 9. get track_data which was stored earlier

# %% [markdown]
# The MIDI file format requires the length field to be exactly 4 bytes long (32 bits). Computers store numbers as a sequence of bytes, and MIDI expects this length in big-endian order (most significant byte first). If we only store len(track_data), it would be a single number, not a properly formatted 4-byte field.

# %%
with open(filename, "wb") as f:
    f.write(header_chunk + track_chunk)
print("File generated")
# Out:
# File generated

# %% [markdown]
# 10. add header_chunk and track_chunk together

# %%
play_midi("output.mid")

# %%
text_from_file = open("frost.txt", "r", encoding="utf-8").read()
text = text_from_file.strip()
print(f"Text from file: {text}")
# Out:
# Text from file: Two roads diverged in a yellow wood
# And sorry I could not travel both
# And be one traveler long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth

# %% [markdown]
# # Takeaway

# %% [markdown]
# ## patterns of sound <> patterns of text/language
